# %% [markdown]
# # Telecom Churn Analysis Report

# %% [markdown]
# ### About

# %% [markdown]
# **Churn is a one of the biggest problem in the telecom industry. Generally, the customers who stop using a product or service for a given period of time are referred to as churners. As a result, churn is one of the most important element in the Key Performance Indicator of a product or service. A full customer lifecycle analysis requires taking a look at retention rates in order to better understand the health of the business or product.
# We will be discussing about Telecom Churn Analysis.**

# %% [markdown]
# ### Context

# %% [markdown]
# **Predict behavior to retain customers. You can analyze all relevant customer data and develop focused customer retention programs.**

# %% [markdown]
# ### Content

# %% [markdown]
# **Each row represents a customer, each column contains customer’s attributes described on the column Metadata.**
#
# **The data set includes information about:**
#
# •	Customers who left within the last month – the column is called Churn.
#
# •	Services that each customer has signed up for – phone, multiple lines, internet, online security, online backup, device protection, tech support, and streaming TV and movies.
#
# •	Customer account information – how long they’ve been a customer, contract, payment method, paperless billing, monthly charges, and total charges.
#
# •	Demographic info about customers – gender, age range, and if they have partners and dependents.**

# %% [markdown]
# ## Visualizations at Elementary level

# %% [markdown]
# **1.Overall Churn Analysis**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *The Churn Customer Percentage is 26.53% of the total record,which is not a large figure. We will focus on those who churn and try to figure out the measures we may take to reduce this churn rate considerably.*

# %% [markdown]
# **2. The Internet Service which is in trend among Customers.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *There are Two types of Internet services provided, first is FIBER OPTICS and another is DSL(Digital Subscriber Line), Here we can see that the use of FIBER OPTICS service is 44% and DSL service is 34.37% and remaining 21.67% customers are not using any InternetServices.*

# %% [markdown]
# **Churn with respect to the Internet service.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *We can easily conclude that people who are using DSL as their internet services are more likely to churn than those who are using Fiber optics. Thus, DSL services need improvement in quality and cost factor so that we can reduce the churn rate.*

# %% [markdown]
# **3. The various plans or contracts used by the customers on the basis of time duration.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *As we talk about the plans used by the customers we can easily coin the conclusion that people nowadays prefer Monthly contracts rather than one year or two year plan.*

# %% [markdown]
# **Contract and Churn...**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **4.How many percentage of customers use Paperless Billing Service ?**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *Around 60% of users are utilising paperless billing service, which somehow indicates that papered billing is not so prefered by the users.*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *Paperless Billing service is very important service ,this service has very less Churn Rate as compare to those who do not use the serices .Then this service has make more user friendly or easy.*

# %% [markdown]
# **5.Analysis on the basis of Tenure.**

# %% [markdown]
# *Tenure is nothing but the Holding time period of services by the users.*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *Maximum people are falling in the category of 1 year tenure.*

# %% [markdown]
# **Churn rate with Tenure year.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *The churn rate is decresing with the tenure time, i.e. We can simply say that new users churn and switch to some other telecom company as compared to those who are using the services for years. With time People get used to with the pattern of services they are using, hence they dont find much reasons to churn. Which intern concludes that companies should provide attractive offers to the users which would result to lesser churn.*

# %% [markdown]
# **6. Payment Method plays a significant role...**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *More people are using Electronic medium than Mailed, Bank transfer and Credit card.*

# %% [markdown]
# **Impact of Payment Method on Churn.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *People nowadays are very busy and can not manage to pay the bills electronically, we should provide users with more options of bank transfer and credit card Payment mode. These are the automatic ways by which one can pay without much efforts.*

# %% [markdown]
# ## Logistic Regression Model

# %% [markdown]
# *Apply Logistic Regression Model Technique has accuracy is 80.12 %. That means the model we created is 80.12% CORRECT. If one new entry comes into existance then we can predict the user will churn or not with the accuracy of 80.12%.*

# %% [markdown]
# ## CONCLUSION:

# %% [markdown]
# **Features such as tenure, Contract, PaperlessBilling, MonthlyCharges and InternetService appear to play a role in customer churn.**
#
# **There does not seem to be a relationship between gender and churn.**
#
# **Customers in a month-to-month contract, with PaperlessBilling and are within 12 months tenure, are more likely to churn; On the other hand, customers with one or two year contract, with longer than 12 months tenure, that are not using PaperlessBilling, are less likely to churn.**

# %% [markdown]
# # THANK-YOU.!
